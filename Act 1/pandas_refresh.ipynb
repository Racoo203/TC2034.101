# %% [markdown]
# # **Bienvenido a TC2034**
#
# Este notebook tiene por objetivo ayudarte con el uso de  pandas.
#
# Pandas es una libreria para procesamiento de datos. Puedes imaginar los dataframes de Pandas como tablas, con filas y columnas.

# %% [markdown]
# **1.-** Importa `pandas` y carga un el dataset desde un archivo

# %%
import pandas as pd

# df es el dataframe
df = pd.read_csv(r"C:\Users\Raul\OneDrive\Escritorio\CS\TC2034.101\data\Video_Games_Sales_as_at_22_Dec_2016.csv")

# %% [markdown]
# La funcion `display(df)` muestra el dataframe. Si hay muchas filas, se mostrara solo un extracto. Prueba esta funcion

# %%
display(df)
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# La funcion `df.head()` devuelve las primeras filas del dataframe. Pruebala. Prueba la funcion `tail`. ¿Que devuelve? Prueba tambien `df.tail()` ¿Que hace?

# %%
# Primeros 5 registros del dataframe
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
df.tail()
# Ultimos 5 registros del dataframe
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16715               LMA Manager 2007     X360           2006.0      Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16717               Spirits & Spells      GBA           2003.0    Platform
# 16718            Winning Post 8 2016      PSV           2016.0  Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 16714    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
# 16715   Codemasters      0.00      0.01      0.00          0.0          0.01
# 16716  Idea Factory      0.00      0.00      0.01          0.0          0.01
# 16717       Wanadoo      0.01      0.00      0.00          0.0          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
#
# ...

# %% [markdown]
# Otras formas utiles para ver informacion del dataset son df.info() y `df.shape`. df.shape devuelve el numero de filas y columnas del dataframe. `df.info()` muestra informacion que incluye los nombres de cada columna, tipo y numero de datos non-null en cada una.

# %%
# nota que shape no es una funcion
df.shape
# Out:
# (16719, 16)

# %%
# prueba df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# ...

# %% [markdown]
# # Acceder a columnas y filas
#
# `df.columns` devuelve el nombre de las columnas. Usala junto a `display` para ver como se llaman las columnas del dataframe

# %%
display(df.columns)
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %% [markdown]
# Para ver los indices de las filas del dataframe puedes usar `df.index`

# %%
df.index
# Out:
# RangeIndex(start=0, stop=16719, step=1)

# %% [markdown]
# Con `df.iloc(i)` podemos acceder a la fila que tenga el indice `i` del dataframe. Por otro lado, `df.index[i]` devuelve el valor del index en la posion `i`. Nota que no son lo mismo.

# %%
df.iloc(0)

# %%
df.iloc[0]
# Out:
# Name               Wii Sports
# Platform                  Wii
# Year_of_Release        2006.0
# Genre                  Sports
# Publisher            Nintendo
# NA_Sales                41.36
# EU_Sales                28.96
# JP_Sales                 3.77
# Other_Sales              8.45
# Global_Sales            82.53
# Critic_Score             76.0
# Critic_Count             51.0
# User_Score                8.0
# User_Count              322.0
# Developer            Nintendo
# Rating                      E
# Name: 0, dtype: object

# %% [markdown]
# # Eliminar filas o columnas
#
# La funcion `df.drop( fila/columna, axis=0/1, inplace=True/False )` sirve para eliminar filas o columnas. El primer parametro es la `fila` o `columna` que queremos eliminar. El segundo es el `axis`, puede ser `0` (para filas) o `1` (para columnas). El tercer parametro inplace puede ser `True` (si la modificion se hara directo sobre `df`) o `False` (si no). En caso de que no, `drop` regresara un nuevo dataframe modificado.

# %%
# se elimina la fila que tenga la posicion 1, directo sobre df
#
df.drop(df.index [ [1] ], axis=0, inplace=True)
df.head()

#   se elimina la columna 3, pero el resultado se relejara en df2 y no en df
# df2 = df.drop(3, axis=1, inplace=False)
df2 = df.drop(df.columns[3], axis=1, inplace=False)

df2.head()
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
# 5                    Tetris       GB           1989.0        Puzzle  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
# 5     23.20      2.26      4.22         0.58         30.26           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# # Renombrar columnas
#
# Nota que las columnas se llaman `0, 1, 2`  etc. La fila 0 tiene los nombres apropiados: `Name, Platform, Year_of_Release,` etc. Podemos asignar a `df.columns` el valor de toda la primera fila, y luego elimarla.

# %%
df.columns = df.iloc[0]
df.drop(df.index[0], axis=0, inplace=True )
display(df.head())

# Cuidado si ejecutas esta celda varias veces, seguiras eliminado filas
# Out:
# 0                Wii Sports  Wii  2006.0        Sports  Nintendo  41.36  \
# 2            Mario Kart Wii  Wii  2008.0        Racing  Nintendo  15.68
# 3         Wii Sports Resort  Wii  2009.0        Sports  Nintendo  15.61
# 4  Pokemon Red/Pokemon Blue   GB  1996.0  Role-Playing  Nintendo  11.27
# 5                    Tetris   GB  1989.0        Puzzle  Nintendo  23.20
# 6     New Super Mario Bros.   DS  2006.0      Platform  Nintendo  11.28
#
# 0  28.96   3.77  8.45  82.53  76.0  51.0  8.0  322.0  Nintendo    E
# 2  12.76   3.79  3.29  35.52  82.0  73.0  8.3  709.0  Nintendo    E
# 3  10.93   3.28  2.95  32.77  80.0  73.0  8.0  192.0  Nintendo    E
# 4   8.89  10.22  1.00  31.37   NaN   NaN  NaN    NaN       NaN  NaN
# 5   2.26   4.22  0.58  30.26   NaN   NaN  NaN    NaN       NaN  NaN
# 6   9.14   6.50  2.88  29.80  89.0  65.0  8.5  431.0  Nintendo    E

# %% [markdown]
# Tambien se puede establecer que el nombre de las columnas esta en la primera fila desde el principio, al abrir el dataframe usando la opcion `header=0`

# %%
df = pd.read_csv(r"C:\Users\Raul\OneDrive\Escritorio\CS\TC2034.101\data\Video_Games_Sales_as_at_22_Dec_2016.csv", header=0 )
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# # Manejar columnas
#
# Podemos acceder a columnas especificas por nombre, por ejemplo `df.Name` . El resultado sera otro dataframe. Tambien puedes seleccionar multiples columnas a la vez usando una lista, por ejemplo `df[['Name', 'Series']]`.

# %%
res = df[['Name', 'Platform'] ] # res es un nuevo dataframe, que contiene solo las columnas Name y Platform de df

# %% [markdown]
# Los nombres de las columnas tambien se pueden usar para eliminarlas con `drop`.  Elimina la columna Global_Sales y muestra el resultado en otro dataframe.

# %%
#drop
dropped = df.drop('Global_Sales', axis = 1)
dropped.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Critic_Score  Critic_Count  \
# 0     41.36     28.96      3.77         8.45          76.0          51.0
# 1     29.08      3.58      6.81         0.77           NaN           NaN
# 2     15.68     12.76      3.79         3.29          82.0          73.0
# 3     15.61     10.93      3.28         2.95          80.0          73.0
# 4     11.27      8.89     10.22         1.00           NaN           NaN
#
#    User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# # Operaciones con columnas
#
# Podemos hacer operaciones con columnas, tanto aritmeticas, como comparaciones. Por ejemplo, `df['NA_Sales'] + df['EU_Sales']` devolvera la suma de ambas columnas.

# %%
df['NA_Sales'] + df['EU_Sales']
# Out:
# 0        70.32
# 1        32.66
# 2        28.44
# 3        26.54
# 4        20.16
#          ...
# 16714     0.00
# 16715     0.01
# 16716     0.00
# 16717     0.01
# 16718     0.00
# Length: 16719, dtype: float64

# %% [markdown]
# # Agregar columnas nuevas
#
# Para agregar columnas nuevas basta con asignarlas. Antes eliminaste la columna Global_Sales. Puedes recalcularla y aregarla de nuevo a partir de la suma de NA_Sales, EU_Sales, JP_Sales y Other_Sales.

# %%
df['nueva_columna'] = df['Name']
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %% [markdown]
# # Manejo de NaN
#
# Algunas columnas tienen valores faltantes (NaN). Por ejemplo, la columna **Critic_Score** tiene celdas con `NaN`. Se puede averiguar cuales datos de **Critic_Score** usando la funcion `isna`. El resultado es una serie de booleanos, donde `True` indica cuales son `NaN`.  La funcion `isnull` es similar a `isna`.

# %%
df['Critic_Score'].isna()
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 16714     True
# 16715     True
# 16716     True
# 16717     True
# 16718     True
# Name: Critic_Score, Length: 16719, dtype: bool

# %% [markdown]
# Es usual elminar los NaN.  La funcion `drop` puede hacerlo si recibe los indices que cumplen la condicion de ser NaN.

# %%
df.drop( df[ df['Critic_Score'].isna() ].index  )
# Out:
#                           Name Platform  Year_of_Release      Genre  \
# 0                   Wii Sports      Wii           2006.0     Sports
# 2               Mario Kart Wii      Wii           2008.0     Racing
# 3            Wii Sports Resort      Wii           2009.0     Sports
# 6        New Super Mario Bros.       DS           2006.0   Platform
# 7                     Wii Play      Wii           2006.0       Misc
# ...                        ...      ...              ...        ...
# 16700                   Breach       PC           2011.0    Shooter
# 16701         Bust-A-Move 3000       GC           2003.0     Puzzle
# 16702         Mega Brain Boost       DS           2008.0     Puzzle
# 16706  STORM: Frontline Nation       PC           2011.0   Strategy
# 16709                  15 Days       PC           2009.0  Adventure
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                   Nintendo     41.36     28.96      3.77         8.45
# ...

# %% [markdown]
# La funcion `fillna` sustituye los `NaN` por otra cosa que se indique. Esta es su sintaxis: `df['columna'] = df['columna'].fillna('valor sustituto')`

# %% [markdown]
# La funcion mean sirve para obtener el promedio. Se puede usar sobre una columna `df['NA_Sales'].mean()`. Por default, `mean` omitira los NaN que existan.

# %%
df['NA_Sales'].mean()
# Out:
# 0.26333034272384714

# %% [markdown]
# Ahora usa `fillna` para sustituir los `NaN` de las columnas numericas

# %%
for column in df.columns:
  if type(column) == 'int64':
    med = df[column].quantile(0.5)
    df[column].fillna(med)
  elif type(column) == 'float64':
    mu = df[column].mean()
    df[column].fillna(mu)

df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %% [markdown]
# # Funciones estadisticas
#
# Funciones como median min, max tambien estan disponibles:

# %%
# si usamos estas funciones sobre todo el dataframe, se aplican a todas las cols. numericas
display( df.mean )

display( df.median  )

display( df.max )

display( df.min  )
# Out:
# <bound method DataFrame.mean of                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# # Ordenamiento
#
# La funcion `sort_values` permite ordenar

# %%
display( df.sort_values('NA_Sales') )  # nota que esto no modifica a df
display(df)

display( df.sort_values('NA_Sales', inplace=True) ) # esto si
display(df)

# sort_values tien otras opciones que puedes consultar aqui
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html
# Out:
#                                                     Name Platform  \
# 8359                                   Bomberman B-Daman     SNES
# 11304                                         Theme Park      SAT
# 11301  Pachitte Chonmage Tatsujin 13: Pachinko Hissat...      PS2
# 11298                     SD Gundam G Generation Genesis      PS4
# 11295                                         Toukiden 2      PS4
# ...                                                  ...      ...
# 2                                         Mario Kart Wii      Wii
# 5                                                 Tetris       GB
# 9                                              Duck Hunt      NES
# 1                                      Super Mario Bros.      NES
# 0                                             Wii Sports      Wii
#
#        Year_of_Release       Genre           Publisher  NA_Sales  EU_Sales  \
# 8359            1996.0     Shooter         Hudson Soft      0.00      0.00
# ...

# %% [markdown]
# Raúl Correa Ocañas
#
# A01722401
#
# 21-02-2024
